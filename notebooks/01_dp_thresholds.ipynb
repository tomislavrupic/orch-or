# %% [markdown]
# # DP Thresholds
#
# Executable HAOS-OR notebook for `tau = hbar / E_G` and tubulin-scale DP threshold sensitivity. Run from the repo root.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))

from orch_or.thresholds import threshold_rows

rows = threshold_rows()
len(rows), rows[0]

# %%
for row in rows:
    if row['target_tau_s'] == '2.500000e-02':
        print(row['mass_model'], row['required_coherent_units'], row['scope'])

# %% [markdown]
# Interpretation boundary: these rows show regulator and mass-model sensitivity. They do not prove a biological coherent domain.

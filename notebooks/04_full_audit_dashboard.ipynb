# %% [markdown]
# # Full Audit Dashboard
#
# Runnable Orch-OR dashboard skeleton for the current frozen spine. It loads the traceable literature registry, runs the main reproduction command, and leaves a clear lane for plots and HTML export without changing the repo's bounded claims.

# %%
from pathlib import Path
import json
import subprocess
import sys

ROOT = Path.cwd()
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))

from orch_or.data import registry

registry.validate()
summary = json.loads((ROOT / 'examples' / 'output' / 'orch_or_summary.json').read_text())
summary['data_registry_validated']

# %%
subprocess.run([sys.executable, 'examples/quick_reproduce.py'], check=True)
print('Reproduction complete; plots can be layered in next.')

# %% [markdown]
# Planned visual layers for this dashboard:
#
# - collapse times vs. `E_G`
# - OR-on vs. OR-off distinction rows
# - literature ranges vs. model outputs
# - reduction event selection and falsifier table
#
# Interpretation boundary: this dashboard is a diagnostic summary, not a claim of solved consciousness.

# %% [markdown]
# # Tryptophan Superradiance and Quantum Optical Channels
#
# Executable HAOS-OR notebook for Trp network size, disorder, quantum-yield, and anesthetic damping diagnostics. This remains a bounded photophysics scaffold, not a consciousness claim.

# %% [markdown]
# Source placeholders and traced references for this module:
#
# - `tryptophan_superradiance_2024`
# - `photoprotection_architectures_2024`
# - `superradiant_excitonic_states_2018`
#
# The sweep below varies network size and disorder to expose the bounded yield proxy.

# %%
from orch_or.trp_networks import tryptophan_network_rows

rows = tryptophan_network_rows(
    network_sizes=(10, 100, 1000, 10000, 100000),
    disorders=(0.0, 0.1, 0.5, 1.0),
    source_ids=(
        "tryptophan_superradiance_2024",
        "photoprotection_architectures_2024",
        "superradiant_excitonic_states_2018",
    ),
    note="Diagnostic tryptophan superradiance sweep; not a consciousness claim.",
    anesthetic_strength=0.3,
)

rows[:3], rows[-3:]

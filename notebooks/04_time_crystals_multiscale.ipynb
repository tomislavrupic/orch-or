# %% [markdown]
# # Time Crystals and Multiscale Oscillations
#
# Executable HAOS-OR notebook for multiscale oscillation diagnostics, beat-frequency proxies, and a phase-trigger collapse surrogate. This is a diagnostic scaffold, not a biological proof.

# %% [markdown]
# Roadmap-linked source placeholders:
#
# - `hameroff_time_crystal_2026`
# - `bandyopadhyay_multiscale_resonance`
#
# The sweep below spans kHz → THz modes and surfaces a simple beat-frequency ladder.

# %%
from orch_or.time_crystal import OscillatorMode, multiscale_oscillation_rows

modes = (
    OscillatorMode("kHz", 1.0e3, 1.0, phase_rad=0.0, damping=0.05),
    OscillatorMode("MHz", 1.0e6, 0.8, phase_rad=0.6, damping=0.1),
    OscillatorMode("GHz", 1.0e9, 0.6, phase_rad=1.0, damping=0.25),
    OscillatorMode("THz", 1.0e12, 0.4, phase_rad=1.3, damping=0.5),
)

rows = multiscale_oscillation_rows(
    modes,
    source_ids=("hameroff_time_crystal_2026", "bandyopadhyay_multiscale_resonance"),
    note="Diagnostic multiscale oscillation ladder; not a biological proof.",
)

rows
